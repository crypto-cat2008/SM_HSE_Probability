# %%
# ChineseRemainderTheorem(n1, r1, n2, r2):
#   (x, y) = ExtendedEuclid(n1, n2)
#     n = x*n1*r2 + y*n2*r1
# return n%(n1*n2)

# %%
def FastModularExponentiation(b, k, m):
    for i in range(k):
        b=(b*b)%m
        print(b,i)
    return b

x = FastModularExponentiation(7, 128, 11)
print('output', x)
# Out:
# 5 0
# 3 1
# 9 2
# 4 3
# 5 4
# 3 5
# 9 6
# 4 7
# 5 8
# 3 9
# 9 10
# 4 11
# 5 12
# 3 13
# 9 14
# 4 15
# 5 16
# 3 17
# 9 18
# 4 19
# 5 20
# 3 21
# 9 22
# 4 23
# 5 24
# 3 25
# 9 26
# 4 27
# 5 28
# 3 29
# 9 30
# 4 31
# 5 32
# 3 33
# 9 34
# 4 35
# 5 36
# 3 37
# 9 38
# 4 39
# 5 40
# 3 41
# 9 42
# 4 43
# 5 44
# 3 45
# 9 46
# 4 47
# 5 48
# 3 49
# 9 50
# 4 51
# 5 52
# 3 53
# 9 54
# 4 55
# 5 56
# 3 57
# 9 58
# 4 59
# 5 60
# 3 61
# 9 62
# 4 63
# 5 64
# 3 65
# 9 66
# 4 67
# 5 68
# 3 69
# 9 70
# 4 71
# 5 72
# 3 73
# 9 74
# 4 75
# 5 76
# 3 77
# 9 78
# 4 79
# 5 80
# 3 81
# 9 82
# 4 83
# 5 84
# 3 85
# 9 86
# 4 87
# 5 88
# 3 89
# 9 90
# 4 91
# 5 92
# 3 93
# 9 94
# 4 95
# 5 96
# 3 97
# 9 98
# 4 99
# 5 100
# 3 101
# 9 102
# 4 103
# 5 104
# 3 105
# 9 106
# 4 107
# 5 108
# 3 109
# 9 110
# 4 111
# 5 112
# 3 113
# 9 114
# 4 115
# 5 116
# 3 117
# 9 118
# 4 119
# 5 120
# 3 121
# 9 122
# 4 123
# 5 124
# 3 125
# 9 126
# 4 127
# output 4

# %%
def fme(b, k, m):
    for i in range(k):
        b=(b*b)%m
        print(b,i)
    return b

def FastModularExponentiation(b, e, m):
    num = bin(e)
    print(num)
    answer = 1
    count = 0
    
    for i in reversed(num):

        if i == '1':
            print(i, count)
            answer *= fme(b, count, m)
            answer = answer%m
        elif i == 'b':
            break
        else:
            print('no', count)
            
        count = count + 1
   
    return answer

x = FastModularExponentiation(7, 13, 11)
print('output', x)
# Out:
# 0b1101
# 1 0
# no 1
# 1 2
# 5 0
# 3 1
# 1 3
# 5 0
# 3 1
# 9 2
# output 2
